# %%
import csv
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, GlobalAveragePooling2D
from keras.datasets import cifar10, mnist, fashion_mnist
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from utils import StateSpace, Controller


NUM_LAYERS = 4
MAX_TRIALS = 20

EPOCHS = 10
BATCHSIZE = 250
EXPLORATION = 0.9
REGULARIZATION = 1e-2
CONTROLLER_CELLS = 32
EMBEDDING_DIM = 20
ACCURACY_BETA = 0.8
CLIP_REWARDS = 0.0
RESTORE_CONTROLLER = True

policy_sess = tf.Session()
K.set_session(policy_sess)

state_space=StateSpace()
state_space.add_state(name='kernel', values=[1, 3])
state_space.add_state(name='filters', values=[32, 48, 64])
state_space.print_state_space()


(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

if K.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 1, 28, 28)
    X_test = X_test.reshape(X_test.shape[0], 1, 28, 28)
    print(X_train.shape)
    input_shape = (1, 28, 28)
else:
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
    X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
    input_shape = (28, 28, 1)
dataset = [X_train, y_train, X_test, y_test]
previous_acc = 0.0
total_reward = 0.0

class NetworkManager:
    def __init__(self, dataset, epochs=5, batchsize=128, acc_beta=0.8, clip_rewards=0.0):
        self.dataset = dataset
        self.epochs = epochs
        self.batchsize = batchsize
        self.clip_rewards = clip_rewards

        self.beta = acc_beta
        self.beta_bias = acc_beta
        self.moving_acc = 0.0
    def get_rewards(self, model_fn, actions):
        with tf.Session(graph=tf.Graph()) as network_sess:
            K.set_session(network_sess)
            model = model_fn(actions)
            model.compile('adam', 'categorical_crossentropy', metrics=['accuracy'])
            X_train, y_train, X_val, y_val = self.dataset
            model.fit(X_train, y_train, batch_size=self.batchsize, epochs=self.epochs,
                      verbose=1, validation_data=(X_val, y_val),
                      callbacks=[ModelCheckpoint('weights/temp_network.h5',
                                                 monitor='val_acc', verbose=1,
                                                 save_best_only=True,
                                                 save_weights_only=True)])
            model.load_weights('weights/temp_network.h5')
            loss, acc = model.evaluate(X_val, y_val, batch_size=self.batchsize)
            reward = (acc - self.moving_acc)
            if self.clip_rewards:
                reward = np.clip(reward, -0.05, 0.05)
            if self.beta > 0.0 and self.beta < 1.0:
                self.moving_acc = self.beta * self.moving_acc + (1 - self.beta) * acc
                self.moving_acc = self.moving_acc / (1 - self.beta_bias)
                self.beta_bias = 0
                reward = np.clip(reward, -0.1, 0.1)
            print()
            print("Manager: EWA Accuracy = ", self.moving_acc)
        network_sess.close()
        return reward, acc


def model_fn(actions):
    kernel_1, filters_1, kernel_2, filters_2, kernel_3, filters_3, kernel_4, filters_4 = actions
    ip = Input(shape=(28, 28, 1))
    x = Conv2D(filters_1, (kernel_1, kernel_1), strides=(2, 2), padding='same', activation='relu')(ip)
    x = Conv2D(filters_2, (kernel_2, kernel_2), strides=(1, 1), padding='same', activation='relu')(x)
    x = Conv2D(filters_3, (kernel_3, kernel_3), strides=(2, 2), padding='same', activation='relu')(x)
    x = Conv2D(filters_4, (kernel_4, kernel_4), strides=(1, 1), padding='same', activation='relu')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(10, activation='softmax')(x)
    model = Model(ip, x)
    return model

with policy_sess.as_default():
    controller = Controller(policy_sess, NUM_LAYERS, state_space,
                            reg_param=REGULARIZATION,
                            exploration=EXPLORATION,
                            controller_cells=CONTROLLER_CELLS,
                            embedding_dim=EMBEDDING_DIM,
                            restore_controller=RESTORE_CONTROLLER)

manager = NetworkManager(dataset, epochs=EPOCHS, batchsize=BATCHSIZE, clip_rewards=CLIP_REWARDS,
                         acc_beta=ACCURACY_BETA)

state = state_space.get_random_state_space(NUM_LAYERS)
print("Initial Random State : ", state_space.parse_state_space_list(state))
print()

accuracy_plot = []
reward_plot = []
loss_plot = []

for trial in range(MAX_TRIALS):
    with policy_sess.as_default():
        K.set_session(policy_sess)
        actions = controller.get_action(state) 

    state_space.print_actions(actions)
    print("Predicted actions : ", state_space.parse_state_space_list(actions))
    
    reward, previous_acc = manager.get_rewards(model_fn, state_space.parse_state_space_list(actions))
    print("Rewards : ", reward, "Accuracy : ", previous_acc)
    reward_plot.append(reward)
    accuracy_plot.append(previous_acc)

    with policy_sess.as_default():
        K.set_session(policy_sess)
        total_reward += reward
        print("Total reward : ", total_reward)
        state = actions
        controller.store_rollout(state, reward)
        loss = controller.train_step()
        loss_plot.append(loss)
        print("Trial %d: Controller loss : %0.6f" % (trial + 1, loss))
        with open('train_history.csv', mode='a+') as f:
            data = [previous_acc, reward]
            data.extend(state_space.parse_state_space_list(state))
            writer = csv.writer(f)
            writer.writerow(data)
    print()
print("Total Reward : ", total_reward)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# **************************************** STATE SPACE ****************************************
# { 'id': 0,
#   'index_map_': {0: 1, 1: 3},
#   'name': 'kernel',
#   'size': 2,
#   'value_map_': {1: 0, 3: 1},
#   'values': [1, 3]}
#
# { 'id': 1,
#   'index_map_': {0: 32, 1: 48, 2: 64},
#   'name': 'filters',
#   'size': 3,
#   'value_map_': {32: 0, 48: 1, 64: 2},
#   'values': [32, 48, 64]}
#
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /content/utils.py:173: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/utils.py:175: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/utils.py:177: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/utils.py:181: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /content/utils.py:187: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/utils.py:203: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /content/utils.py:205: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/utils.py:217: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/utils.py:217: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/utils.py:221: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /content/utils.py:224: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/utils.py:225: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /content/utils.py:257: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /content/utils.py:261: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /content/utils.py:263: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/utils.py:264: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Initial Random State :  [3, 48, 1, 64, 3, 64, 3, 48]
#
# Generating random action to explore
# Actions :
# ******************** Layer 1 ********************
# kernel :  [(1, 0.0), (3, 2.0)]
# filters :  [(32, 0.0), (48, 0.0), (64, 3.0)]
# ******************** Layer 2 ********************
# kernel :  [(1, 1.0), (3, 0.0)]
# filters :  [(32, 0.0), (48, 0.0), (64, 3.0)]
# ******************** Layer 3 ********************
# kernel :  [(1, 1.0), (3, 0.0)]
# filters :  [(32, 0.0), (48, 0.0), (64, 3.0)]
# ******************** Layer 4 ********************
# kernel :  [(1, 0.0), (3, 2.0)]
# filters :  [(32, 0.0), (48, 2.0), (64, 0.0)]
#
# Predicted actions :  [3, 64, 1, 64, 1, 64, 3, 48]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60000/60000 [==============================] - 8s 131us/step - loss: 1.2878 - acc: 0.5417 - val_loss: 0.8249 - val_acc: 0.7207
#
# Epoch 00001: val_acc improved from -inf to 0.72070, saving model to weights/temp_network.h5
# Epoch 2/50
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.7396 - acc: 0.7435 - val_loss: 0.6896 - val_acc: 0.7641
#
# Epoch 00002: val_acc improved from 0.72070 to 0.76410, saving model to weights/temp_network.h5
# Epoch 3/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.6526 - acc: 0.7696 - val_loss: 0.6498 - val_acc: 0.7651
#
# Epoch 00003: val_acc improved from 0.76410 to 0.76510, saving model to weights/temp_network.h5
# Epoch 4/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.6091 - acc: 0.7833 - val_loss: 0.6094 - val_acc: 0.7863
#
# Epoch 00004: val_acc improved from 0.76510 to 0.78630, saving model to weights/temp_network.h5
# Epoch 5/50
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.5791 - acc: 0.7952 - val_loss: 0.6001 - val_acc: 0.7830
#
# Epoch 00005: val_acc did not improve from 0.78630
# Epoch 6/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.5642 - acc: 0.7995 - val_loss: 0.5713 - val_acc: 0.7964
#
# Epoch 00006: val_acc improved from 0.78630 to 0.79640, saving model to weights/temp_network.h5
# Epoch 7/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.5371 - acc: 0.8099 - val_loss: 0.5610 - val_acc: 0.7980
#
# Epoch 00007: val_acc improved from 0.79640 to 0.79800, saving model to weights/temp_network.h5
# Epoch 8/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.5276 - acc: 0.8118 - val_loss: 0.5641 - val_acc: 0.7912
#
# Epoch 00008: val_acc did not improve from 0.79800
# Epoch 9/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.5094 - acc: 0.8180 - val_loss: 0.5203 - val_acc: 0.8116
#
# Epoch 00009: val_acc improved from 0.79800 to 0.81160, saving model to weights/temp_network.h5
# Epoch 10/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.5035 - acc: 0.8189 - val_loss: 0.4993 - val_acc: 0.8250
#
# Epoch 00010: val_acc improved from 0.81160 to 0.82500, saving model to weights/temp_network.h5
# Epoch 11/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4864 - acc: 0.8252 - val_loss: 0.4989 - val_acc: 0.8188
#
# Epoch 00011: val_acc did not improve from 0.82500
# Epoch 12/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4786 - acc: 0.8280 - val_loss: 0.5196 - val_acc: 0.8083
#
# Epoch 00012: val_acc did not improve from 0.82500
# Epoch 13/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.4654 - acc: 0.8330 - val_loss: 0.4753 - val_acc: 0.8322
#
# Epoch 00013: val_acc improved from 0.82500 to 0.83220, saving model to weights/temp_network.h5
# Epoch 14/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4590 - acc: 0.8339 - val_loss: 0.4781 - val_acc: 0.8336
#
# Epoch 00014: val_acc improved from 0.83220 to 0.83360, saving model to weights/temp_network.h5
# Epoch 15/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.4542 - acc: 0.8360 - val_loss: 0.5049 - val_acc: 0.8085
#
# Epoch 00015: val_acc did not improve from 0.83360
# Epoch 16/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4414 - acc: 0.8405 - val_loss: 0.4570 - val_acc: 0.8370
#
# Epoch 00016: val_acc improved from 0.83360 to 0.83700, saving model to weights/temp_network.h5
# Epoch 17/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4336 - acc: 0.8439 - val_loss: 0.4604 - val_acc: 0.8303
#
# Epoch 00017: val_acc did not improve from 0.83700
# Epoch 18/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4363 - acc: 0.8410 - val_loss: 0.4475 - val_acc: 0.8407
#
# Epoch 00018: val_acc improved from 0.83700 to 0.84070, saving model to weights/temp_network.h5
# Epoch 19/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.4181 - acc: 0.8491 - val_loss: 0.4555 - val_acc: 0.8383
#
# Epoch 00019: val_acc did not improve from 0.84070
# Epoch 20/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.4170 - acc: 0.8492 - val_loss: 0.4711 - val_acc: 0.8276
#
# Epoch 00020: val_acc did not improve from 0.84070
# Epoch 21/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.4184 - acc: 0.8475 - val_loss: 0.4337 - val_acc: 0.8464
#
# Epoch 00021: val_acc improved from 0.84070 to 0.84640, saving model to weights/temp_network.h5
# Epoch 22/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4041 - acc: 0.8534 - val_loss: 0.4291 - val_acc: 0.8452
#
# Epoch 00022: val_acc did not improve from 0.84640
# Epoch 23/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4041 - acc: 0.8534 - val_loss: 0.4164 - val_acc: 0.8508
#
# Epoch 00023: val_acc improved from 0.84640 to 0.85080, saving model to weights/temp_network.h5
# Epoch 24/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3984 - acc: 0.8554 - val_loss: 0.4215 - val_acc: 0.8526
#
# Epoch 00024: val_acc improved from 0.85080 to 0.85260, saving model to weights/temp_network.h5
# Epoch 25/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3841 - acc: 0.8611 - val_loss: 0.4113 - val_acc: 0.8572
#
# Epoch 00025: val_acc improved from 0.85260 to 0.85720, saving model to weights/temp_network.h5
# Epoch 26/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3883 - acc: 0.8587 - val_loss: 0.4049 - val_acc: 0.8555
#
# Epoch 00026: val_acc did not improve from 0.85720
# Epoch 27/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3773 - acc: 0.8632 - val_loss: 0.4095 - val_acc: 0.8533
#
# Epoch 00027: val_acc did not improve from 0.85720
# Epoch 28/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3772 - acc: 0.8627 - val_loss: 0.4067 - val_acc: 0.8559
#
# Epoch 00028: val_acc did not improve from 0.85720
# Epoch 29/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3760 - acc: 0.8631 - val_loss: 0.4162 - val_acc: 0.8494
#
# Epoch 00029: val_acc did not improve from 0.85720
# Epoch 30/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3690 - acc: 0.8653 - val_loss: 0.3988 - val_acc: 0.8580
#
# Epoch 00030: val_acc improved from 0.85720 to 0.85800, saving model to weights/temp_network.h5
# Epoch 31/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3587 - acc: 0.8691 - val_loss: 0.3837 - val_acc: 0.8620
#
# Epoch 00031: val_acc improved from 0.85800 to 0.86200, saving model to weights/temp_network.h5
# Epoch 32/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3613 - acc: 0.8666 - val_loss: 0.3861 - val_acc: 0.8607
#
# Epoch 00032: val_acc did not improve from 0.86200
# Epoch 33/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3559 - acc: 0.8714 - val_loss: 0.4121 - val_acc: 0.8535
#
# Epoch 00033: val_acc did not improve from 0.86200
# Epoch 34/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3510 - acc: 0.8729 - val_loss: 0.3964 - val_acc: 0.8581
#
# Epoch 00034: val_acc did not improve from 0.86200
# Epoch 35/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3515 - acc: 0.8722 - val_loss: 0.3775 - val_acc: 0.8656
#
# Epoch 00035: val_acc improved from 0.86200 to 0.86560, saving model to weights/temp_network.h5
# Epoch 36/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3472 - acc: 0.8742 - val_loss: 0.4143 - val_acc: 0.8491
#
# Epoch 00036: val_acc did not improve from 0.86560
# Epoch 37/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3392 - acc: 0.8769 - val_loss: 0.4161 - val_acc: 0.8468
#
# Epoch 00037: val_acc did not improve from 0.86560
# Epoch 38/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3388 - acc: 0.8760 - val_loss: 0.3874 - val_acc: 0.8626
#
# Epoch 00038: val_acc did not improve from 0.86560
# Epoch 39/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3363 - acc: 0.8776 - val_loss: 0.3740 - val_acc: 0.8665
#
# Epoch 00039: val_acc improved from 0.86560 to 0.86650, saving model to weights/temp_network.h5
# Epoch 40/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3395 - acc: 0.8764 - val_loss: 0.3598 - val_acc: 0.8710
#
# Epoch 00040: val_acc improved from 0.86650 to 0.87100, saving model to weights/temp_network.h5
# Epoch 41/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3291 - acc: 0.8803 - val_loss: 0.3613 - val_acc: 0.8719
#
# Epoch 00041: val_acc improved from 0.87100 to 0.87190, saving model to weights/temp_network.h5
# Epoch 42/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3278 - acc: 0.8810 - val_loss: 0.3671 - val_acc: 0.8689
#
# Epoch 00042: val_acc did not improve from 0.87190
# Epoch 43/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3245 - acc: 0.8822 - val_loss: 0.3595 - val_acc: 0.8706
#
# Epoch 00043: val_acc did not improve from 0.87190
# Epoch 44/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3219 - acc: 0.8837 - val_loss: 0.3743 - val_acc: 0.8659
#
# Epoch 00044: val_acc did not improve from 0.87190
# Epoch 45/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3200 - acc: 0.8831 - val_loss: 0.3519 - val_acc: 0.8738
#
# Epoch 00045: val_acc improved from 0.87190 to 0.87380, saving model to weights/temp_network.h5
# Epoch 46/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3180 - acc: 0.8845 - val_loss: 0.3551 - val_acc: 0.8739
#
# Epoch 00046: val_acc improved from 0.87380 to 0.87390, saving model to weights/temp_network.h5
# Epoch 47/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3149 - acc: 0.8847 - val_loss: 0.3584 - val_acc: 0.8725
#
# Epoch 00047: val_acc did not improve from 0.87390
# Epoch 48/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3140 - acc: 0.8851 - val_loss: 0.3569 - val_acc: 0.8701
#
# Epoch 00048: val_acc did not improve from 0.87390
# Epoch 49/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3116 - acc: 0.8864 - val_loss: 0.3472 - val_acc: 0.8783
#
# Epoch 00049: val_acc improved from 0.87390 to 0.87830, saving model to weights/temp_network.h5
# Epoch 50/50
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.3113 - acc: 0.8872 - val_loss: 0.3869 - val_acc: 0.8649
#
# Epoch 00050: val_acc did not improve from 0.87830
# 10000/10000 [==============================] - 0s 19us/step
#
# Manager: EWA Accuracy =  0.8782999992370606
# Rewards :  0.1 Accuracy :  0.8782999992370606
# Total reward :  0.1
# State input to Controller for training :  [0 2]
# Training RNN (States ip) :  [3, 64, 1, 64, 1, 64, 3, 48]
# Training RNN (Reward ip) :  [0.1]
# Trial 1: Controller loss : 17.417162
#
# Generating random action to explore
# Actions :
# ******************** Layer 1 ********************
# kernel :  [(1, 1.0), (3, 0.0)]
# filters :  [(32, 1.0), (48, 0.0), (64, 0.0)]
# ******************** Layer 2 ********************
# kernel :  [(1, 0.0), (3, 2.0)]
# filters :  [(32, 1.0), (48, 0.0), (64, 0.0)]
# ******************** Layer 3 ********************
# kernel :  [(1, 1.0), (3, 0.0)]
# filters :  [(32, 1.0), (48, 0.0), (64, 0.0)]
# ******************** Layer 4 ********************
# kernel :  [(1, 0.0), (3, 2.0)]
# filters :  [(32, 1.0), (48, 0.0), (64, 0.0)]
#
# Predicted actions :  [1, 32, 3, 32, 1, 32, 3, 32]
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 57us/step - loss: 1.3443 - acc: 0.5071 - val_loss: 0.8830 - val_acc: 0.6746
#
# Epoch 00001: val_acc improved from -inf to 0.67460, saving model to weights/temp_network.h5
# Epoch 2/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.8219 - acc: 0.6981 - val_loss: 0.7862 - val_acc: 0.7099
#
# Epoch 00002: val_acc improved from 0.67460 to 0.70990, saving model to weights/temp_network.h5
# Epoch 3/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.7571 - acc: 0.7198 - val_loss: 0.7374 - val_acc: 0.7322
#
# Epoch 00003: val_acc improved from 0.70990 to 0.73220, saving model to weights/temp_network.h5
# Epoch 4/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.7145 - acc: 0.7360 - val_loss: 0.7036 - val_acc: 0.7420
#
# Epoch 00004: val_acc improved from 0.73220 to 0.74200, saving model to weights/temp_network.h5
# Epoch 5/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.6929 - acc: 0.7424 - val_loss: 0.7152 - val_acc: 0.7344
#
# Epoch 00005: val_acc did not improve from 0.74200
# Epoch 6/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.6696 - acc: 0.7527 - val_loss: 0.6704 - val_acc: 0.7442
#
# Epoch 00006: val_acc improved from 0.74200 to 0.74420, saving model to weights/temp_network.h5
# Epoch 7/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.6444 - acc: 0.7612 - val_loss: 0.6695 - val_acc: 0.7501
#
# Epoch 00007: val_acc improved from 0.74420 to 0.75010, saving model to weights/temp_network.h5
# Epoch 8/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.6281 - acc: 0.7689 - val_loss: 0.6303 - val_acc: 0.7635
#
# Epoch 00008: val_acc improved from 0.75010 to 0.76350, saving model to weights/temp_network.h5
# Epoch 9/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.6140 - acc: 0.7718 - val_loss: 0.6220 - val_acc: 0.7746
#
# Epoch 00009: val_acc improved from 0.76350 to 0.77460, saving model to weights/temp_network.h5
# Epoch 10/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.5995 - acc: 0.7785 - val_loss: 0.6294 - val_acc: 0.7619
#
# Epoch 00010: val_acc did not improve from 0.77460
# Epoch 11/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.5847 - acc: 0.7850 - val_loss: 0.6140 - val_acc: 0.7757
#
# Epoch 00011: val_acc improved from 0.77460 to 0.77570, saving model to weights/temp_network.h5
# Epoch 12/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.5751 - acc: 0.7860 - val_loss: 0.5922 - val_acc: 0.7790
#
# Epoch 00012: val_acc improved from 0.77570 to 0.77900, saving model to weights/temp_network.h5
# Epoch 13/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.5585 - acc: 0.7969 - val_loss: 0.5882 - val_acc: 0.7843
#
# Epoch 00013: val_acc improved from 0.77900 to 0.78430, saving model to weights/temp_network.h5
# Epoch 14/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.5477 - acc: 0.8001 - val_loss: 0.5721 - val_acc: 0.7847
#
# Epoch 00014: val_acc improved from 0.78430 to 0.78470, saving model to weights/temp_network.h5
# Epoch 15/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.5361 - acc: 0.8061 - val_loss: 0.5591 - val_acc: 0.7958
#
# Epoch 00015: val_acc improved from 0.78470 to 0.79580, saving model to weights/temp_network.h5
# Epoch 16/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.5270 - acc: 0.8074 - val_loss: 0.5590 - val_acc: 0.7968
#
# Epoch 00016: val_acc improved from 0.79580 to 0.79680, saving model to weights/temp_network.h5
# Epoch 17/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.5150 - acc: 0.8141 - val_loss: 0.5578 - val_acc: 0.7986
#
# Epoch 00017: val_acc improved from 0.79680 to 0.79860, saving model to weights/temp_network.h5
# Epoch 18/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.5081 - acc: 0.8177 - val_loss: 0.5374 - val_acc: 0.8077
#
# Epoch 00018: val_acc improved from 0.79860 to 0.80770, saving model to weights/temp_network.h5
# Epoch 19/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.5038 - acc: 0.8170 - val_loss: 0.5290 - val_acc: 0.8115
#
# Epoch 00019: val_acc improved from 0.80770 to 0.81150, saving model to weights/temp_network.h5
# Epoch 20/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.4928 - acc: 0.8202 - val_loss: 0.5255 - val_acc: 0.8144
#
# Epoch 00020: val_acc improved from 0.81150 to 0.81440, saving model to weights/temp_network.h5
# Epoch 21/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4810 - acc: 0.8260 - val_loss: 0.5193 - val_acc: 0.8080
#
# Epoch 00021: val_acc did not improve from 0.81440
# Epoch 22/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4772 - acc: 0.8272 - val_loss: 0.5053 - val_acc: 0.8191
#
# Epoch 00022: val_acc improved from 0.81440 to 0.81910, saving model to weights/temp_network.h5
# Epoch 23/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4733 - acc: 0.8280 - val_loss: 0.5069 - val_acc: 0.8209
#
# Epoch 00023: val_acc improved from 0.81910 to 0.82090, saving model to weights/temp_network.h5
# Epoch 24/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4690 - acc: 0.8294 - val_loss: 0.5018 - val_acc: 0.8229
#
# Epoch 00024: val_acc improved from 0.82090 to 0.82290, saving model to weights/temp_network.h5
# Epoch 25/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.4598 - acc: 0.8331 - val_loss: 0.4843 - val_acc: 0.8301
#
# Epoch 00025: val_acc improved from 0.82290 to 0.83010, saving model to weights/temp_network.h5
# Epoch 26/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.4564 - acc: 0.8347 - val_loss: 0.4967 - val_acc: 0.8241
#
# Epoch 00026: val_acc did not improve from 0.83010
# Epoch 27/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4477 - acc: 0.8380 - val_loss: 0.4817 - val_acc: 0.8270
#
# Epoch 00027: val_acc did not improve from 0.83010
# Epoch 28/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4531 - acc: 0.8359 - val_loss: 0.4977 - val_acc: 0.8225
#
# Epoch 00028: val_acc did not improve from 0.83010
# Epoch 29/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.4394 - acc: 0.8398 - val_loss: 0.4835 - val_acc: 0.8234
#
# Epoch 00029: val_acc did not improve from 0.83010
# Epoch 30/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4379 - acc: 0.8400 - val_loss: 0.4711 - val_acc: 0.8337
#
# Epoch 00030: val_acc improved from 0.83010 to 0.83370, saving model to weights/temp_network.h5
# Epoch 31/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4330 - acc: 0.8430 - val_loss: 0.4588 - val_acc: 0.8375
#
# Epoch 00031: val_acc improved from 0.83370 to 0.83750, saving model to weights/temp_network.h5
# Epoch 32/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4254 - acc: 0.8450 - val_loss: 0.4725 - val_acc: 0.8307
#
# Epoch 00032: val_acc did not improve from 0.83750
# Epoch 33/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.4217 - acc: 0.8469 - val_loss: 0.4652 - val_acc: 0.8338
#
# Epoch 00033: val_acc did not improve from 0.83750
# Epoch 34/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4187 - acc: 0.8482 - val_loss: 0.4586 - val_acc: 0.8381
#
# Epoch 00034: val_acc improved from 0.83750 to 0.83810, saving model to weights/temp_network.h5
# Epoch 35/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4136 - acc: 0.8504 - val_loss: 0.4719 - val_acc: 0.8326
#
# Epoch 00035: val_acc did not improve from 0.83810
# Epoch 36/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4122 - acc: 0.8502 - val_loss: 0.4524 - val_acc: 0.8407
#
# Epoch 00036: val_acc improved from 0.83810 to 0.84070, saving model to weights/temp_network.h5
# Epoch 37/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4082 - acc: 0.8528 - val_loss: 0.4786 - val_acc: 0.8334
#
# Epoch 00037: val_acc did not improve from 0.84070
# Epoch 38/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4053 - acc: 0.8524 - val_loss: 0.4371 - val_acc: 0.8407
#
# Epoch 00038: val_acc improved from 0.84070 to 0.84070, saving model to weights/temp_network.h5
# Epoch 39/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4025 - acc: 0.8540 - val_loss: 0.4362 - val_acc: 0.8449
#
# Epoch 00039: val_acc improved from 0.84070 to 0.84490, saving model to weights/temp_network.h5
# Epoch 40/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.4008 - acc: 0.8555 - val_loss: 0.4506 - val_acc: 0.8373
#
# Epoch 00040: val_acc did not improve from 0.84490
# Epoch 41/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3911 - acc: 0.8583 - val_loss: 0.4265 - val_acc: 0.8494
#
# Epoch 00041: val_acc improved from 0.84490 to 0.84940, saving model to weights/temp_network.h5
# Epoch 42/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3889 - acc: 0.8578 - val_loss: 0.4249 - val_acc: 0.8472
#
# Epoch 00042: val_acc did not improve from 0.84940
# Epoch 43/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3912 - acc: 0.8576 - val_loss: 0.4240 - val_acc: 0.8475
#
# Epoch 00043: val_acc did not improve from 0.84940
# Epoch 44/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3852 - acc: 0.8598 - val_loss: 0.4445 - val_acc: 0.8414
#
# Epoch 00044: val_acc did not improve from 0.84940
# Epoch 45/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3825 - acc: 0.8609 - val_loss: 0.4197 - val_acc: 0.8487
#
# Epoch 00045: val_acc did not improve from 0.84940
# Epoch 46/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3791 - acc: 0.8620 - val_loss: 0.4272 - val_acc: 0.8478
#
# Epoch 00046: val_acc did not improve from 0.84940
# Epoch 47/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3800 - acc: 0.8614 - val_loss: 0.4151 - val_acc: 0.8528
#
# Epoch 00047: val_acc improved from 0.84940 to 0.85280, saving model to weights/temp_network.h5
# Epoch 48/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3722 - acc: 0.8657 - val_loss: 0.4301 - val_acc: 0.8439
#
# Epoch 00048: val_acc did not improve from 0.85280
# Epoch 49/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.3729 - acc: 0.8648 - val_loss: 0.4175 - val_acc: 0.8474
#
# Epoch 00049: val_acc did not improve from 0.85280
# Epoch 50/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3745 - acc: 0.8641 - val_loss: 0.4218 - val_acc: 0.8516
#
# Epoch 00050: val_acc did not improve from 0.85280
# 10000/10000 [==============================] - 0s 16us/step
#
# Manager: EWA Accuracy =  0.8731999999284744
# Rewards :  -0.02549999654293067 Accuracy :  0.8528000026941299
# Total reward :  0.07450000345706934
# State input to Controller for training :  [1 0]
# Training RNN (States ip) :  [1, 32, 3, 32, 1, 32, 3, 32]
# Training RNN (Reward ip) :  [-0.0255]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Trial 2: Controller loss : 10.302886
#
# Prediction action from Controller
# State input to Controller for Action :  [1. 0.]
# Actions :
# ******************** Layer 1 ********************
# kernel :  [(1, 0.46802774), (3, 0.5319723)]
# filters :  [(32, 0.3144198), (48, 0.32797632), (64, 0.3576039)]
# ******************** Layer 2 ********************
# kernel :  [(1, 0.53291357), (3, 0.46708646)]
# filters :  [(32, 0.3619815), (48, 0.3200364), (64, 0.31798208)]
# ******************** Layer 3 ********************
# kernel :  [(1, 0.48994696), (3, 0.51005304)]
# filters :  [(32, 0.30246803), (48, 0.27624467), (64, 0.4212873)]
# ******************** Layer 4 ********************
# kernel :  [(1, 0.45253998), (3, 0.54746)]
# filters :  [(32, 0.30850473), (48, 0.3848276), (64, 0.30666766)]
#
# Predicted actions :  [3, 64, 1, 32, 3, 64, 3, 48]
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 71us/step - loss: 1.1403 - acc: 0.5858 - val_loss: 0.7608 - val_acc: 0.7272
#
# Epoch 00001: val_acc improved from -inf to 0.72720, saving model to weights/temp_network.h5
# Epoch 2/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.6988 - acc: 0.7473 - val_loss: 0.7040 - val_acc: 0.7476
#
# Epoch 00002: val_acc improved from 0.72720 to 0.74760, saving model to weights/temp_network.h5
# Epoch 3/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.6204 - acc: 0.7774 - val_loss: 0.5870 - val_acc: 0.7922
#
# Epoch 00003: val_acc improved from 0.74760 to 0.79220, saving model to weights/temp_network.h5
# Epoch 4/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.5700 - acc: 0.7967 - val_loss: 0.5653 - val_acc: 0.8055
#
# Epoch 00004: val_acc improved from 0.79220 to 0.80550, saving model to weights/temp_network.h5
# Epoch 5/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.5261 - acc: 0.8141 - val_loss: 0.5183 - val_acc: 0.8220
#
# Epoch 00005: val_acc improved from 0.80550 to 0.82200, saving model to weights/temp_network.h5
# Epoch 6/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.4807 - acc: 0.8309 - val_loss: 0.4958 - val_acc: 0.8329
#
# Epoch 00006: val_acc improved from 0.82200 to 0.83290, saving model to weights/temp_network.h5
# Epoch 7/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4568 - acc: 0.8385 - val_loss: 0.4982 - val_acc: 0.8251
#
# Epoch 00007: val_acc did not improve from 0.83290
# Epoch 8/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4351 - acc: 0.8460 - val_loss: 0.4627 - val_acc: 0.8320
#
# Epoch 00008: val_acc did not improve from 0.83290
# Epoch 9/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4118 - acc: 0.8535 - val_loss: 0.4328 - val_acc: 0.8462
#
# Epoch 00009: val_acc improved from 0.83290 to 0.84620, saving model to weights/temp_network.h5
# Epoch 10/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3979 - acc: 0.8585 - val_loss: 0.4279 - val_acc: 0.8458
#
# Epoch 00010: val_acc did not improve from 0.84620
# Epoch 11/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3820 - acc: 0.8629 - val_loss: 0.3935 - val_acc: 0.8595
#
# Epoch 00011: val_acc improved from 0.84620 to 0.85950, saving model to weights/temp_network.h5
# Epoch 12/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3726 - acc: 0.8647 - val_loss: 0.3920 - val_acc: 0.8637
#
# Epoch 00012: val_acc improved from 0.85950 to 0.86370, saving model to weights/temp_network.h5
# Epoch 13/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3645 - acc: 0.8690 - val_loss: 0.3931 - val_acc: 0.8599
#
# Epoch 00013: val_acc did not improve from 0.86370
# Epoch 14/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3518 - acc: 0.8736 - val_loss: 0.3873 - val_acc: 0.8601
#
# Epoch 00014: val_acc did not improve from 0.86370
# Epoch 15/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3481 - acc: 0.8733 - val_loss: 0.3713 - val_acc: 0.8699
#
# Epoch 00015: val_acc improved from 0.86370 to 0.86990, saving model to weights/temp_network.h5
# Epoch 16/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3336 - acc: 0.8800 - val_loss: 0.3633 - val_acc: 0.8694
#
# Epoch 00016: val_acc did not improve from 0.86990
# Epoch 17/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.3283 - acc: 0.8814 - val_loss: 0.3711 - val_acc: 0.8685
#
# Epoch 00017: val_acc did not improve from 0.86990
# Epoch 18/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3239 - acc: 0.8814 - val_loss: 0.3677 - val_acc: 0.8726
#
# Epoch 00018: val_acc improved from 0.86990 to 0.87260, saving model to weights/temp_network.h5
# Epoch 19/50
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.3187 - acc: 0.8839 - val_loss: 0.3513 - val_acc: 0.8749
#
# Epoch 00019: val_acc improved from 0.87260 to 0.87490, saving model to weights/temp_network.h5
# Epoch 20/50
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.3151 - acc: 0.8854 - val_loss: 0.3412 - val_acc: 0.8780
#
# Epoch 00020: val_acc improved from 0.87490 to 0.87800, saving model to weights/temp_network.h5
# Epoch 21/50
# 50750/60000 [========================>.....] - ETA: 0s - loss: 0.3108 - acc: 0.8851

# %%
import matplotlib.pyplot as plt
import os

plt.xticks(range(1,21,2))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(sorted(accuracy_plot))
plt.savefig('plots/accuracy.png')

# %%
plt.xticks(range(1,21,2))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(loss_plot)
plt.savefig('plots/loss.png')

# %%
plt.xticks(range(1,21,2))
plt.xlabel('Epochs')
plt.ylabel('Rewards')
plt.plot(reward_plot)
plt.savefig('plots/reward.png')
